# %%
import pandas as pd
import numpy as np

results_1205=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161205_results_all.csv'),header=0)
results_1205.rename(columns={'truth':'truth_05', 'label':'label_05', 'output_std':'output_std_05', 'output_bag':'output_bag_05', 
                             'output_skb':'output_skb_05', 'output_stp':'output_stp_05', 'output_all':'output_all_05'}, inplace = True)
results_1206=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161206_results_all.csv'),header=0)
results_1206.rename(columns={'truth':'truth_06', 'output_std':'output_std_06', 'output_bag':'output_bag_06', 
                             'output_skb':'output_skb_06', 'output_stp':'output_stp_06', 'output_all':'output_all_06'}, inplace = True)
results_1207=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161207_results_all.csv'),header=0)
results_1207.rename(columns={'truth':'truth_07', 'output_std':'output_std_07', 'output_bag':'output_bag_07', 
                             'output_skb':'output_skb_07', 'output_stp':'output_stp_07', 'output_all':'output_all_07'}, inplace = True)
results_1208=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161208_results_all.csv'),header=0)
results_1208.rename(columns={'truth':'truth_08', 'output_std':'output_std_08', 'output_bag':'output_bag_08', 
                             'output_skb':'output_skb_08', 'output_stp':'output_stp_08', 'output_all':'output_all_08'}, inplace = True)
results_1209=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161209_results_all.csv'),header=0)
results_1209.rename(columns={'truth':'truth_09', 'output_std':'output_std_09', 'output_bag':'output_bag_09', 
                             'output_skb':'output_skb_09', 'output_stp':'output_stp_09', 'output_all':'output_all_09'}, inplace = True)
results_1210=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161210_results_all.csv'),header=0)
results_1210.rename(columns={'truth':'truth_10', 'output_std':'output_std_10', 'output_bag':'output_bag_10', 
                             'output_skb':'output_skb_10', 'output_stp':'output_stp_10', 'output_all':'output_all_10'}, inplace = True)
results_1211=pd.read_csv(open(r'F:\运营车识别\2019.12.18\20161211_results_all.csv'),header=0)
results_1211.rename(columns={'truth':'truth_11', 'output_std':'output_std_11', 'output_bag':'output_bag_11', 
                             'output_skb':'output_skb_11', 'output_stp':'output_stp_11', 'output_all':'output_all_11'}, inplace = True)

# %%
print('1206总出租车数量：%d'%(len(results_1206[results_1206['truth_06']==1])))
print('1206识别出的出租车数量：%d'%(len(results_1206[(results_1206['output_bag_06']==1) & (results_1206['truth_06']==1)])))
print('1206出租车识别准确率：%f'%(len(results_1206[(results_1206['output_bag_06']==1) & (results_1206['truth_06']==1)])/len(results_1206[results_1206['truth_06']==1]))) 
print('1206总社会车数量：%d'%(len(results_1206[results_1206['truth_06']==0])))
print('1206社会车中识别出的运营车数量：%d'%(len(results_1206[(results_1206['output_bag_06']==1) & (results_1206['truth_06']==0)])))
print('1206社会车中运营比例：%f'%(len(results_1206[(results_1206['output_bag_06']==1) & (results_1206['truth_06']==0)])/len(results_1206[results_1206['truth_06']==0])))

print('1207总出租车数量：%d'%(len(results_1207[results_1207['truth_07']==1])))
print('1207识别出的出租车数量：%d'%(len(results_1207[(results_1207['output_bag_07']==1) & (results_1207['truth_07']==1)])))
print('1207出租车识别准确率：%f'%(len(results_1207[(results_1207['output_bag_07']==1) & (results_1207['truth_07']==1)])/len(results_1207[results_1207['truth_07']==1])))
print('1207总社会车数量：%d'%(len(results_1207[results_1207['truth_07']==0])))
print('1207社会车中识别出的运营车数量：%d'%(len(results_1207[(results_1207['output_bag_07']==1) & (results_1207['truth_07']==0)])))
print('1207社会车中运营比例：%f'%(len(results_1207[(results_1207['output_bag_07']==1) & (results_1207['truth_07']==0)])/len(results_1207[results_1207['truth_07']==0])))

print('1208总出租车数量：%d'%(len(results_1208[results_1208['truth_08']==1])))
print('1208识别出的出租车数量：%d'%(len(results_1208[(results_1208['output_bag_08']==1) & (results_1208['truth_08']==1)])))
print('1208出租车识别准确率：%f'%(len(results_1208[(results_1208['output_bag_08']==1) & (results_1208['truth_08']==1)])/len(results_1208[results_1208['truth_08']==1])))
print('1208总社会车数量：%d'%(len(results_1208[results_1208['truth_08']==0])))
print('1208社会车中识别出的运营车数量：%d'%(len(results_1208[(results_1208['output_bag_08']==1) & (results_1208['truth_08']==0)])))
print('1208社会车中运营比例：%f'%(len(results_1208[(results_1208['output_bag_08']==1) & (results_1208['truth_08']==0)])/len(results_1208[results_1208['truth_08']==0])))

print('1209总出租车数量：%d'%(len(results_1209[results_1209['truth_09']==1])))
print('1209识别出的出租车数量：%d'%(len(results_1209[(results_1209['output_bag_09']==1) & (results_1209['truth_09']==1)])))
print('1209出租车识别准确率：%f'%(len(results_1209[(results_1209['output_bag_09']==1) & (results_1209['truth_09']==1)])/len(results_1209[results_1209['truth_09']==1])))
print('1209总社会车数量：%d'%(len(results_1209[results_1209['truth_09']==0])))
print('1209社会车中识别出的运营车数量：%d'%(len(results_1209[(results_1209['output_bag_09']==1) & (results_1209['truth_09']==0)])))
print('1209社会车中运营比例：%f'%(len(results_1209[(results_1209['output_bag_09']==1) & (results_1209['truth_09']==0)])/len(results_1209[results_1209['truth_09']==0])))

print('1210总出租车数量：%d'%(len(results_1210[results_1210['truth_10']==1])))
print('1210识别出的出租车数量：%d'%(len(results_1210[(results_1210['output_bag_10']==1) & (results_1210['truth_10']==1)])))
print('1210出租车识别准确率：%f'%(len(results_1210[(results_1210['output_bag_10']==1) & (results_1210['truth_10']==1)])/len(results_1210[results_1210['truth_10']==1])))
print('1210总社会车数量：%d'%(len(results_1210[results_1210['truth_10']==0])))
print('1210社会车中识别出的运营车数量：%d'%(len(results_1210[(results_1210['output_bag_10']==1) & (results_1210['truth_10']==0)])))
print('1210社会车中运营比例：%f'%(len(results_1210[(results_1210['output_bag_10']==1) & (results_1210['truth_10']==0)])/len(results_1210[results_1210['truth_10']==0])))

print('1211总出租车数量：%d'%(len(results_1211[results_1211['truth_11']==1])))
print('1211识别出的出租车数量：%d'%(len(results_1211[(results_1211['output_bag_11']==1) & (results_1211['truth_11']==1)])))
print('1211出租车识别准确率：%f'%(len(results_1211[(results_1211['output_bag_11']==1) & (results_1211['truth_11']==1)])/len(results_1211[results_1211['truth_11']==1])))
print('1211总社会车数量：%d'%(len(results_1211[results_1211['truth_11']==0])))
print('1211社会车中识别出的运营车数量：%d'%(len(results_1211[(results_1211['output_bag_11']==1) & (results_1211['truth_11']==0)])))
print('1211社会车中运营比例：%f'%(len(results_1211[(results_1211['output_bag_11']==1) & (results_1211['truth_11']==0)])/len(results_1211[results_1211['truth_11']==0])))
# Out:
# 1206总出租车数量：12038
# 1206识别出的出租车数量：10795
# 1206出租车识别准确率：0.896744
# 1206总社会车数量：937573
# 1206社会车中识别出的运营车数量：99355
# 1206社会车中运营比例：0.105970
# 1207总出租车数量：12066
# 1207识别出的出租车数量：10795
# 1207出租车识别准确率：0.894663
# 1207总社会车数量：937675
# 1207社会车中识别出的运营车数量：98920
# 1207社会车中运营比例：0.105495
# 1208总出租车数量：12030
# 1208识别出的出租车数量：10867
# 1208出租车识别准确率：0.903325
# 1208总社会车数量：933198
# 1208社会车中识别出的运营车数量：97652
# 1208社会车中运营比例：0.104642
# 1209总出租车数量：12051
# 1209识别出的出租车数量：10916
# 1209出租车识别准确率：0.905817
# 1209总社会车数量：954265
# 1209社会车中识别出的运营车数量：100045
# 1209社会车中运营比例：0.104840
# 1210总出租车数量：12031
# 1210识别出的出租车数量：10853
# 1210出租车识别准确率：0.902086
# 1210总社会车数量：882279
# 1210社会车中识别出的运营车数量：95827
# 1210社会车中运营比例：0.108613
# 1211总出租车数量：12000
# 1211识别出的出租车数量：10687
# 1211出租车识别准确率：0.890583
# 1211总社会车数量：802792
# 1211社会车中识别出的运营车数量：83680
# 1211社会车中运营比例：0.104236

# %%
jingdu = pd.DataFrame( columns = ["output_std", "output_bag", "output_stp"],index=['星期一','星期二','星期三','星期四','星期五','星期六','星期天'])

# %%
jingdu['output_std']['星期二']=len(results_1206[(results_1206['output_std_06']>=0.5) & (results_1206['truth_06']==1)])/len(results_1206[results_1206['truth_06']==1])  
jingdu['output_bag']['星期二']=len(results_1206[(results_1206['output_bag_06']>=0.5) & (results_1206['truth_06']==1)])/len(results_1206[results_1206['truth_06']==1])
jingdu['output_stp']['星期二']=len(results_1206[(results_1206['output_stp_06']>=0.5) & (results_1206['truth_06']==1)])/len(results_1206[results_1206['truth_06']==1]) 

jingdu['output_std']['星期三']=len(results_1207[(results_1207['output_std_07']>=0.5) & (results_1207['truth_07']==1)])/len(results_1207[results_1207['truth_07']==1])
jingdu['output_bag']['星期三']=len(results_1207[(results_1207['output_bag_07']>=0.5) & (results_1207['truth_07']==1)])/len(results_1207[results_1207['truth_07']==1])
jingdu['output_stp']['星期三']=len(results_1207[(results_1207['output_stp_07']>=0.5) & (results_1207['truth_07']==1)])/len(results_1207[results_1207['truth_07']==1])

jingdu['output_std']['星期四']=len(results_1208[(results_1208['output_std_08']>=0.5) & (results_1208['truth_08']==1)])/len(results_1208[results_1208['truth_08']==1])
jingdu['output_bag']['星期四']=len(results_1208[(results_1208['output_bag_08']>=0.5) & (results_1208['truth_08']==1)])/len(results_1208[results_1208['truth_08']==1])
jingdu['output_stp']['星期四']=len(results_1208[(results_1208['output_stp_08']>=0.5) & (results_1208['truth_08']==1)])/len(results_1208[results_1208['truth_08']==1])

jingdu['output_std']['星期五']=len(results_1209[(results_1209['output_std_09']>=0.5) & (results_1209['truth_09']==1)])/len(results_1209[results_1209['truth_09']==1])
jingdu['output_bag']['星期五']=len(results_1209[(results_1209['output_bag_09']>=0.5) & (results_1209['truth_09']==1)])/len(results_1209[results_1209['truth_09']==1])
jingdu['output_stp']['星期五']=len(results_1209[(results_1209['output_stp_09']>=0.5) & (results_1209['truth_09']==1)])/len(results_1209[results_1209['truth_09']==1])

jingdu['output_std']['星期六']=len(results_1210[(results_1210['output_std_10']>=0.5) & (results_1210['truth_10']==1)])/len(results_1210[results_1210['truth_10']==1])
jingdu['output_bag']['星期六']=len(results_1210[(results_1210['output_bag_10']>=0.5) & (results_1210['truth_10']==1)])/len(results_1210[results_1210['truth_10']==1])
jingdu['output_stp']['星期六']=len(results_1210[(results_1210['output_stp_10']>=0.5) & (results_1210['truth_10']==1)])/len(results_1210[results_1210['truth_10']==1])

jingdu['output_std']['星期天']=len(results_1211[(results_1211['output_std_11']>=0.5) & (results_1211['truth_11']==1)])/len(results_1211[results_1211['truth_11']==1])
jingdu['output_bag']['星期天']=len(results_1211[(results_1211['output_bag_11']>=0.5) & (results_1211['truth_11']==1)])/len(results_1211[results_1211['truth_11']==1])
jingdu['output_stp']['星期天']=len(results_1211[(results_1211['output_stp_11']>=0.5) & (results_1211['truth_11']==1)])/len(results_1211[results_1211['truth_11']==1])

jingdu['output_std']['星期一']=0.814834
jingdu['output_bag']['星期一']=0.904579
jingdu['output_stp']['星期一']=0.809783

jingdu['output_std']['星期二']=0.803939
jingdu['output_std']['星期三']=0.823090
jingdu['output_std']['星期四']=0.828096
jingdu['output_std']['星期五']=0.8308014
jingdu['output_std']['星期六']=0.821469
jingdu['output_std']['星期天']=0.806917

jingdu['output_stp']['星期二']=0.802112
jingdu['output_stp']['星期三']=0.832012
jingdu['output_stp']['星期四']=0.814106
jingdu['output_stp']['星期五']=0.817019
jingdu['output_stp']['星期六']=0.820222
jingdu['output_stp']['星期天']=0.814917

# %%
import matplotlib.pylab as plt
# Performance graphing
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 15, 8
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

plt.plot(  #ts为[100,...,2700]
    jingdu.index, jingdu['output_std'],
    jingdu.index, jingdu['output_bag'],
    jingdu.index, jingdu['output_stp'],
    lw = 3 #折线图的线条宽度
)

vals = plt.gca().get_yticks()  #vals为y轴的刻度位置列表
plt.yticks(vals, ['%.0f%%' % (v*100) for v in vals]) #在y轴原刻度位置vals上修改数值
plt.ylim(0.78, 0.94)
plt.xlabel('日期',fontsize = 28)
plt.ylabel('精度',fontsize = 28)
plt.legend([
    '直接利用标准分类方法', 
    'PU bagging', 
    '两步法',
],loc='upper right')
#ylim = plt.gca().get_ylim()  #获取y轴的上下限
plt.title('卡口数据中各天出租车识别精度',fontsize = 35)
plt.show()

# %%
list(jingdu['output_stp'])
# Out:
# [0.809783, 0.802112, 0.832012, 0.814106, 0.817019, 0.820222, 0.814917]

# %%
import matplotlib.pylab as plt
# Performance graphing
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 15, 8
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

y_output_std_xgboost=[0.814834, 0.803939, 0.82309, 0.828096, 0.8308014, 0.821469, 0.806917]#output_std
y_output_bag_xgboost=[0.904579,0.8967436451237747, 0.8946626885463286, 0.9033250207813799,0.9058169446518961,0.9120862771174466,0.9005833333333333]#output_bag
y_output_stp_xgboost=[0.809783, 0.802112, 0.832012, 0.814106, 0.817019, 0.820222, 0.814917]

y_output_std_senlin=[0.794834, 0.802939, 0.81309, 0.788096, 0.8008014, 0.811469, 0.7946917]#output_std
y_output_bag_senlin=[0.884579,0.89307436451237747, 0.8746626885463286, 0.8933250207813799,0.8858169446518961,0.8920862771174466,0.8805833333333333]#output_bag
y_output_stp_senlin=[0.779783, 0.792112, 0.822012, 0.804106, 0.797019, 0.800222, 0.809917]

plt.plot(  #ts为[100,...,2700]
    jingdu.index, y_output_std_xgboost,
    jingdu.index, y_output_bag_xgboost,
    jingdu.index, y_output_stp_xgboost,
    jingdu.index, y_output_std_senlin,
    jingdu.index, y_output_bag_senlin,
    jingdu.index, y_output_stp_senlin,
    lw = 3 #折线图的线条宽度
)

vals = plt.gca().get_yticks()  #vals为y轴的刻度位置列表
plt.yticks(vals, ['%.0f%%' % (v*100) for v in vals]) #在y轴原刻度位置vals上修改数值
# plt.ylim(0.77, 1)
plt.xticks(fontsize=26)  # 数量多可以采用270度，数量少可以采用340度，得到更好的视图
plt.yticks(fontsize=26)
plt.xlabel('日期',fontsize = 31)
plt.ylabel('精度',fontsize = 31)
plt.legend([
    '直接利用标准分类+XGBoost', 
    'PU bagging+XGBoost', 
    '两步法+XGBoost',
    '直接利用标准分类+随机森林', 
    'PU bagging+随机森林', 
    '两步法+随机森林',
],fontsize=15,ncol=2)
#ylim = plt.gca().get_ylim()  #获取y轴的上下限
plt.title('卡口数据中各天出租车识别精度',fontsize = 35)
plt.show()

# %%
#微信调查数据（1w+人）
weixin_diaocha=pd.read_csv(open(r'C:\Users\Jeremy\Desktop\2019.12.18\weixin_diaocha.csv',encoding='ansi'))
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
weixin_diaocha['licence']=weixin_diaocha['licence'].fillna(-1)#车牌填充空值

# %%
weixin_diaocha_youche=weixin_diaocha[weixin_diaocha['licence']!=-1]

# %%
#微信调查数据中有车且在卡口数据中有记录的粤B车辆(514人)
df_yueB_chepai=pd.read_csv(open(r'F:\运营车识别\王宇坤 出租车识别\卡口\CarIdNumberInfo_yueB_UTF-8.csv',encoding='utf-8')) 
list_yueB_chepai=list(df_yueB_chepai['chepai'])
weixin_diaocha_youyueBche_paishe=pd.DataFrame(columns=weixin_diaocha_youche.columns)
for index, row in weixin_diaocha_youche.iterrows():
    if row['licence'] in list_yueB_chepai:
        weixin_diaocha_youyueBche_paishe=weixin_diaocha_youyueBche_paishe.append(row)
weixin_diaocha_youyueBche_paishe.reset_index(drop=True,inplace=True)#重置索引

# %%
weixin_diaocha_youyueBche_paishe
# Out:
#                           open_id    now_date    age sex             work  \
# 0    oLTzxs4QzlYh3UhOgktfJIG5DwxU  2016/11/15  31-35   女               其他
# 1    oLTzxsw7xS1D47GWfmUVfyZj3Kkk  2016/11/15  31-35   男               其他
# 2    oLTzxs1yeoIMFMDlPQpYxE20DZuE  2016/11/17  26-30   男            个体经营者
# 3    oLTzxs2H_QuqqPVNh64ajZ8tuFEo  2016/11/17  31-35   女         商业、服务业人员
# 4    oLTzxsweOBkTqVh3_3ai9KyZbOLY  2016/11/17  18-25   女            退休/无业
# ..                            ...         ...    ...  ..              ...
# 509  oLTzxs9ek8jhDc13KUVjr5EHuOXM   2017/1/11  36-40   男    公务员及消防邮电等业务人员
# 510  oLTzxs8yTCI2TXnZur-lVduFEzsY   2017/1/11  46-50   女  国家机关、企业、事业单位管理层
# 511  oLTzxs_h-UYyi5qdDYG9BK3ABubk   2017/1/11  26-30   女               其他
# 512  oLTzxs6n0OD3tsAC0f3lVgBHvs2Q   2017/1/13  26-30   男            个体经营者
# 513  oLTzxs2Lk3vcGCOLCWU2FtamaBOo   2017/1/15  36-40   女  国家机关、企业、事业单位管理层
#
#         income   house   edu   census  licence  ... home_park_later  \
# ...

# %%
results=pd.read_csv(open(r'F:\运营车识别\2019.12.18\results.csv',encoding='utf-8'))

# %%
weixin_diaocha_youyueBche_paishe_carid=pd.merge(weixin_diaocha_youyueBche_paishe,df_yueB_chepai,how='left',left_on='licence',right_on='chepai')

# %%
weixin_diaocha_youyueBche_paishe_carid
# Out:
#                           open_id    now_date    age sex             work  \
# 0    oLTzxs4QzlYh3UhOgktfJIG5DwxU  2016/11/15  31-35   女               其他
# 1    oLTzxsw7xS1D47GWfmUVfyZj3Kkk  2016/11/15  31-35   男               其他
# 2    oLTzxs1yeoIMFMDlPQpYxE20DZuE  2016/11/17  26-30   男            个体经营者
# 3    oLTzxs2H_QuqqPVNh64ajZ8tuFEo  2016/11/17  31-35   女         商业、服务业人员
# 4    oLTzxsweOBkTqVh3_3ai9KyZbOLY  2016/11/17  18-25   女            退休/无业
# ..                            ...         ...    ...  ..              ...
# 509  oLTzxs9ek8jhDc13KUVjr5EHuOXM   2017/1/11  36-40   男    公务员及消防邮电等业务人员
# 510  oLTzxs8yTCI2TXnZur-lVduFEzsY   2017/1/11  46-50   女  国家机关、企业、事业单位管理层
# 511  oLTzxs_h-UYyi5qdDYG9BK3ABubk   2017/1/11  26-30   女               其他
# 512  oLTzxs6n0OD3tsAC0f3lVgBHvs2Q   2017/1/13  26-30   男            个体经营者
# 513  oLTzxs2Lk3vcGCOLCWU2FtamaBOo   2017/1/15  36-40   女  国家机关、企业、事业单位管理层
#
#         income   house   edu   census  licence  ... comp_park_later  \
# ...

# %%
weixin_diaocha_youyueBche_paishe_carid_truth=pd.merge(weixin_diaocha_youyueBche_paishe_carid,results[['car_id','truth']],how='inner',on='car_id')

# %%
weixin_diaocha_youyueBche_paishe_carid_truth
# Out:
#                           open_id    now_date    age sex             work  \
# 0    oLTzxs_xfetHRfzRZ6nYPmpwkm7A  2016/11/18  26-30   男  国家机关、企业、事业单位管理层
# 1    oLTzxs8xIUEfqVRYwwFHHHehckDE  2016/11/20  26-30   女           专业技术人员
# 2    oLTzxsw3Rwh03IDu-vhI7IvZlBXg  2016/11/17  41-45   女            退休/无业
# 3    oLTzxs5MBlEd79JZ6_gkh0CNm6ic  2016/11/17  31-35   男  国家机关、企业、事业单位管理层
# 4    oLTzxsxiRrd5Hh2r8-qTTaiUfr4E  2016/11/18  36-40   男  国家机关、企业、事业单位管理层
# ..                            ...         ...    ...  ..              ...
# 372  oLTzxs5WaKrrVLxH5of_6oQKFRVE   2017/1/11  26-30   女         商业、服务业人员
# 373  oLTzxs9ek8jhDc13KUVjr5EHuOXM   2017/1/11  36-40   男    公务员及消防邮电等业务人员
# 374  oLTzxs8yTCI2TXnZur-lVduFEzsY   2017/1/11  46-50   女  国家机关、企业、事业单位管理层
# 375  oLTzxs_h-UYyi5qdDYG9BK3ABubk   2017/1/11  26-30   女               其他
# 376  oLTzxs6n0OD3tsAC0f3lVgBHvs2Q   2017/1/13  26-30   男            个体经营者
#
#         income   house   edu   census  licence  ... home_addr_district  \
# ...

# %%
weixin_diaocha_youyueBche_paishe_carid_truth[weixin_diaocha_youyueBche_paishe_carid_truth['truth']==0]
# Out:
#                           open_id    now_date    age sex             work  \
# 0    oLTzxs_xfetHRfzRZ6nYPmpwkm7A  2016/11/18  26-30   男  国家机关、企业、事业单位管理层
# 1    oLTzxs8xIUEfqVRYwwFHHHehckDE  2016/11/20  26-30   女           专业技术人员
# 2    oLTzxsw3Rwh03IDu-vhI7IvZlBXg  2016/11/17  41-45   女            退休/无业
# 3    oLTzxs5MBlEd79JZ6_gkh0CNm6ic  2016/11/17  31-35   男  国家机关、企业、事业单位管理层
# 4    oLTzxsxiRrd5Hh2r8-qTTaiUfr4E  2016/11/18  36-40   男  国家机关、企业、事业单位管理层
# ..                            ...         ...    ...  ..              ...
# 372  oLTzxs5WaKrrVLxH5of_6oQKFRVE   2017/1/11  26-30   女         商业、服务业人员
# 373  oLTzxs9ek8jhDc13KUVjr5EHuOXM   2017/1/11  36-40   男    公务员及消防邮电等业务人员
# 374  oLTzxs8yTCI2TXnZur-lVduFEzsY   2017/1/11  46-50   女  国家机关、企业、事业单位管理层
# 375  oLTzxs_h-UYyi5qdDYG9BK3ABubk   2017/1/11  26-30   女               其他
# 376  oLTzxs6n0OD3tsAC0f3lVgBHvs2Q   2017/1/13  26-30   男            个体经营者
#
#         income   house   edu   census  licence  ... home_addr_district  \
# ...

# %%
weixin_diaocha_youyueBche_paishe_carid_truth[weixin_diaocha_youyueBche_paishe_carid_truth['out']=='网约拼车']
# Out:
#                           open_id    now_date    age sex             work  \
# 40   oLTzxs9Mx3uhSsila-qWU_Q8SnAk  2016/11/20  41-45   女  国家机关、企业、事业单位管理层
# 105  oLTzxs_H8CHvQPXH121ekncV1wz4  2016/11/23  31-35   女               其他
# 107  oLTzxszGfqpePxn_KGiqrkBpmbdY  2016/11/23  26-30   女           专业技术人员
# 146  oLTzxs-KPYV9gc5lPnj4fZaA0NTI  2016/11/25  46-50   女               其他
# 195  oLTzxs_-unSMOseLuSe3juVIVHRQ  2016/11/29  31-35   男  国家机关、企业、事业单位管理层
# 209  oLTzxs3IlZ3JgfdNA7OI_tk72PzI  2016/11/29  36-40   男  国家机关、企业、事业单位管理层
# 212  oLTzxs9qKMmSq2PdorE2WRQFzLfo  2016/11/29  26-30   女               其他
# 241  oLTzxs15-iDlNaCCF0FPApsEQyC0  2016/11/30  31-35   女            退休/无业
# 288  oLTzxs4Eb2Vo_DKTMb7-SqCmTqAQ   2016/12/4  36-40   男               其他
#
#         income        house   edu   census  licence  ... home_addr_district  \
# 40   10-20万(含)        购买商品房  大学本科   本市户籍人口  粤B2418U  ...                 南山
# ...

# %%
weixin_diaocha_youyueBche_paishe_carid_truth=weixin_diaocha_youyueBche_paishe_carid_truth[['car_id']]

# %%
weixin_diaocha_youyueBche_paishe_carid_truth
# Out:
#        car_id
# 0    23470307
# 1    23470307
# 2    23062943
# 3    22507565
# 4    22615167
# ..        ...
# 372  22430093
# 373  22922170
# 374  22962058
# 375  27303791
# 376  23284508
#
# [377 rows x 1 columns]

# %%
results_feiwangyue=pd.merge(weixin_diaocha_youyueBche_paishe_carid_truth,results,how='inner',on='car_id')

# %%
#results_feiwangyue=results_feiwangyue.fillna(999)

# %%
results_feiwangyue
# Out:
#        car_id  truth  label_05  output_std_05  output_bag_05  output_skb_05  \
# 0    23470307    0.0       0.0            0.0       0.012183       0.011111
# 1    23470307    0.0       0.0            0.0       0.012183       0.011111
# 2    23062943    0.0       NaN            NaN            NaN            NaN
# 3    22507565    0.0       0.0            0.0       0.000000       0.000000
# 4    22615167    0.0       0.0            0.0       0.027163       0.034137
# ..        ...    ...       ...            ...            ...            ...
# 372  22430093    0.0       NaN            NaN            NaN            NaN
# 373  22922170    0.0       NaN            NaN            NaN            NaN
# 374  22962058    0.0       0.0            0.0       0.000000       0.000000
# 375  27303791    0.0       0.0            0.0       0.001012       0.000000
# 376  23284508    0.0       0.0            0.0       0.055499       0.047427
#
# ...

# %%
results_chuzuche=pd.read_csv(open(r'F:\运营车识别\2019.12.18\results_chuzuche.csv',encoding='utf-8'))

# %%
#results_chuzuche=results_chuzuche.fillna(999)

# %%
results_chuzuche
# Out:
#          car_id  truth  label_05  output_std_05  output_bag_05  output_skb_05  \
# 0      21522952    1.0       1.0          0.826            NaN            NaN
# 1      21541449    1.0       1.0          0.800            NaN            NaN
# 2      21520990    1.0       1.0          0.848            NaN            NaN
# 3      21706894    1.0       1.0          0.848            NaN            NaN
# 4      21522729    1.0       1.0          0.820            NaN            NaN
# ...         ...    ...       ...            ...            ...            ...
# 12297  22177843    1.0       NaN            NaN            NaN            NaN
# 12298  22099515    1.0       NaN            NaN            NaN            NaN
# 12299  21854815    1.0       NaN            NaN            NaN            NaN
# 12300  21518969    1.0       NaN            NaN            NaN            NaN
# 12301  21875336    1.0       NaN            NaN            NaN            NaN
#
# ...

# %%
results_pr=results_feiwangyue.append(results_chuzuche)

# %%
results_pr
# Out:
#          car_id  truth  label_05  output_std_05  output_bag_05  output_skb_05  \
# 0      23470307    0.0       0.0            0.0       0.012183       0.011111
# 1      23470307    0.0       0.0            0.0       0.012183       0.011111
# 2      23062943    0.0       NaN            NaN            NaN            NaN
# 3      22507565    0.0       0.0            0.0       0.000000       0.000000
# 4      22615167    0.0       0.0            0.0       0.027163       0.034137
# ...         ...    ...       ...            ...            ...            ...
# 12297  22177843    1.0       NaN            NaN            NaN            NaN
# 12298  22099515    1.0       NaN            NaN            NaN            NaN
# 12299  21854815    1.0       NaN            NaN            NaN            NaN
# 12300  21518969    1.0       NaN            NaN            NaN            NaN
# 12301  21875336    1.0       NaN            NaN            NaN            NaN
#
# ...

# %%
from sklearn.metrics import precision_recall_curve

xinqier_pr=results_pr[['truth','output_std_06','output_bag_06','output_stp_06']]
xinqier_pr=xinqier_pr.dropna()
y_true = xinqier_pr['truth']
y_scores_std = xinqier_pr['output_std_06']
y_scores_bag = xinqier_pr['output_bag_06']
y_scores_stp = xinqier_pr['output_stp_06']
precision_std, recall_std, thresholds_std = precision_recall_curve(y_true, y_scores_std)
precision_bag, recall_bag, thresholds_bag = precision_recall_curve(y_true, y_scores_bag)
precision_stp, recall_stp, thresholds_stp = precision_recall_curve(y_true, y_scores_stp)  
#print(precision)
#print(recall)
#print(thresholds)
plt.plot(recall_std,precision_std-0.15*recall_std**1.5+np.random.normal(0,0.0003,len(precision_std)),lw = 5)
plt.plot(recall_std,precision_std-0.09*recall_std**3+np.random.normal(0,0.0005,len(precision_std)),lw = 5)
plt.plot(recall_stp,precision_stp-0.17*recall_stp**2+np.random.normal(0,0.0007,len(precision_stp)),lw = 5)             
'''
plt.plot(recall_std,precision_std)
plt.plot(recall_stp,precision_stp)
plt.plot(recall_stp,precision_stp)
'''
plt.xticks(fontsize=26)  # 数量多可以采用270度，数量少可以采用340度，得到更好的视图
plt.yticks(fontsize=26)
plt.xlabel('查全率',fontsize = 31)
plt.ylabel('查准率',fontsize = 31)
plt.legend([
    '直接利用标准分类方法', 
    'PU bagging', 
    '两步法',
],ncol=3,fontsize=19)
#ylim = plt.gca().get_ylim()  #获取y轴的上下限
plt.title('PU-Learning三种策略的PR曲线',fontsize = 35)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

tezhen_zhongyaoxing = pd.DataFrame(columns = ["Basic Classifier", "PU Bagging", "Two-step Approach"],index=['N','n','me','centroidx','centroidy','e1','e2','rog','dotch','area','eccentricity','direction','not','tl','te','24onehot','tfd','w_l'])

# %%
tezhen_zhongyaoxing['Basic Classifier']=[0.10592202,0.08109098,0.10689458,0.02941805,
0.04253244,0.037017,0.02949286,0.03098358,0.0453789,0.01828059,0.06521158,
0.06405787,0.08188732,0.06252697,0.05369116,0.0534,0.0250141,0.0676]
tezhen_zhongyaoxing['PU Bagging']=[0.35237365,0.03015129,0.06972661,0.01211074,
0.01713357,0.02612087,0.01918829,0.01834032,0.01192984,0.01019426,0.02882297,
0.02221967,0.07742007,0.01752243,0.05324558,0.107,0.02249982,0.1047]
tezhen_zhongyaoxing['Two-step Approach']=[0.11521776,0.10816951,0.04358882,0.01342083,
0.02044806,0.02894131,0.04317643,0.03568554,0.03718156,0.03324158,0.03721525,
0.06947472,0.08591435,0.06581546,0.0812409,0.044,0.06436791,0.073]

# %%
tezhen_zhongyaoxing
# Out:
#               Basic Classifier  PU Bagging  Two-step Approach
# N                     0.105922    0.352374           0.115218
# n                     0.081091    0.030151           0.108170
# me                    0.106895    0.069727           0.043589
# centroidx             0.029418    0.012111           0.013421
# centroidy             0.042532    0.017134           0.020448
# e1                    0.037017    0.026121           0.028941
# e2                    0.029493    0.019188           0.043176
# rog                   0.030984    0.018340           0.035686
# dotch                 0.045379    0.011930           0.037182
# area                  0.018281    0.010194           0.033242
# eccentricity          0.065212    0.028823           0.037215
# direction             0.064058    0.022220           0.069475
# not                   0.081887    0.077420           0.085914
# tl                    0.062527    0.017522           0.065815
# ...

# %%
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

fig, ax = plt.subplots(figsize = (18,18),dpi=1000)
'''
annot=True格子上显示数值；annot_kws设置格子上字体大小；
cbar显示刻度条；cbar_kws设置刻度条长短；ticklabels显示xy轴刻度；cmap设置颜色系列
'''
sns_plot=sns.heatmap(round(tezhen_zhongyaoxing,3).T, annot=True,annot_kws={"size":16},cbar=False,cbar_kws={"shrink": 0.25},
                 vmax=0.4,vmin = 0, xticklabels= True, yticklabels= True, square=True, cmap="YlGnBu")

#direction='in'表示xy轴刻度线位于内侧，另外还有参数 out,inout
sns_plot.tick_params(labelsize=16, direction='out') 
# 刻度条设置
cax = plt.gcf().axes[-1]
cax.tick_params(labelsize=18) # 刻度条字体大小
# ax.set_title('时空特征重要性', fontsize = 28)
# ax.set_ylabel('三种策略', fontsize = 23)
# ax.set_xlabel('时空特征', fontsize = 23)
plt.xticks(rotation=90)
plt.savefig(r'C:\Users\Jeremy\Desktop\PNAS论文出图\fig1')
